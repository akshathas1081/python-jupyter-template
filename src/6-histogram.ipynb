# %% [markdown]
# ### Exercise 6: Histogram Customization

# %%
# TASK: Create a histogram for the following data: data = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4, 5].
# Customize the histogram with a title, labels for the x-axis, and a specific color for the bars.

# %%
import matplotlib.pyplot as plt

data = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4, 5]

plt.hist(data, bins=5, color='skyblue', edgecolor='black') # bins=5 for each unique value, edgecolor adds a visible border

plt.title('Histogram of Data')
plt.xlabel('Data Values')
plt.ylabel('Frequency')  # Added y-axis label
plt.xticks(range(1, 6)) #Set x-axis ticks to be integers from 1 to 5
plt.show()
